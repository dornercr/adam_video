# %%
import pandas as pd

# Load the CSV file
file_path1 = "levant_output_with_ilr_3_12_25.csv"  # Change to your actual file path
df1 = pd.read_csv(file_path1)

df1 = pd.read_csv(file_path1)
# Display column names
print("Columns in the CSV file:")
print(df1.columns)
# Display first few rows


file_path2 = "egypt_arabic_transcripts_3_13_25_with_transcript.csv"  # Change to your actual file path
df2 = pd.read_csv(file_path2)

# Display column names
print("Columns in the CSV file:")
print(df2.columns)

# Display first few rows


file_path3 = "gulf_arabic_transcripts_3_13_25_with_transcript.csv"  # Change to your actual file path
df3 = pd.read_csv(file_path3)



# Rename 'URL' column to 'url' if it exists
if 'arabic_transcript' in df3.columns:
    df3.rename(columns={'arabic_transcript': 'transcript'}, inplace=True)


# Save the CSV files back as is
df3.to_csv(file_path3, index=False)
# Display column names
print("Columns in the CSV file:")
print(df3.columns)

print(df1.head())
# Display first few rows
print(df3.head())

# Display first few rows
print(df2.head())
# Out:
# Columns in the CSV file:
# Index(['region', 'category', 'searchTerm', 'dialect', 'title', 'url',
#        'video_id', 'transcript', 'ilr_quantized', 'ilr_range',
#        'ilr_regressed'],
#       dtype='object')
# Columns in the CSV file:
# Index(['region', 'category', 'searchTerm', 'dialect', 'title', 'url',
#        'video_id', 'arabic_transcript', 'ilr_quantized', 'ilr_range',
#        'ilr_regressed'],
#       dtype='object')
# Columns in the CSV file:
# Index(['region', 'category', 'searchTerm', 'dialect', 'title', 'url',
#        'video_id', 'transcript', 'ilr_quantized', 'ilr_range',
#        'ilr_regressed'],
#       dtype='object')
#   region                                           category  \
# 0     SA  Socialize with a professional contact (formall...
# 1     SA  Socialize with a professional contact (formall...
# 2     SA  Socialize with a professional contact (formall...
# 3     SA  Socialize with a professional contact (formall...
# ...

# %%
import pandas as pd

file_path1 = "levant_output_with_ilr_3_12_25.csv"  # Change to your actual file path
df1 = pd.read_csv(file_path1)

# Rename 'URL' column to 'url' if it exists
# Rename 'URL' column to 'url' if it exists
if 'arabic_transcript' in df1.columns:
    df1.rename(columns={'arabic_transcript': 'transcript'}, inplace=True)


# Save the CSV files back as is
df1.to_csv(file_path1, index=False)

print("Column renamed and files saved successfully.")
# Out:
# Column renamed and files saved successfully.

# %%
import pandas as pd

# Load the CSV files
file_path2 = "egypt_arabic_transcripts_3_13_25_with_transcript.csv"
df2 = pd.read_csv(file_path2)

file_path3 = "gulf_arabic_transcripts_3_13_25_with_transcript.csv"
df3 = pd.read_csv(file_path3)

# Rename all values in the "dialect" column
df2["dialect"] = "Egypt"
df3["dialect"] = "Gulf"

# Save the updated files if needed
df2.to_csv(file_path2, index=False)
df3.to_csv(file_path3, index=False)

# Verify changes
print(df2["dialect"].unique())  # Should output ['egypt']
print(df3["dialect"].unique())  # Should output ['gulf']
# Out:
# ['Egypt']
# ['Gulf']
